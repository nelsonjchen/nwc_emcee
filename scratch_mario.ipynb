# %% [markdown]
# # Scratch

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('sheets/mario.png')

RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
HSV_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
GRAY_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(RGB_img, cmap='Greys_r')
plt.title('my picture')
plt.show()


lower_white = np.array([0, 0, 0])
upper_white = np.array([85, 255, 255])

_, masked= cv2.threshold(GRAY_img, 10, 255, cv2.THRESH_BINARY)
masked = cv2.bitwise_not(masked)

plt.imshow(masked, cmap="Greys")
plt.title('greens')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-b9cfb3d795df> in <module>
#      11 masked = cv2.bitwise_not(masked)
#      12
# ---> 13 plt.imshow(masked, cmap="Greys")
#      14 plt.title('greens')
#      15 plt.show()
#
# <ipython-input-24-b9cfb3d795df> in <module>
#      11 masked = cv2.bitwise_not(masked)
#      12
# ---> 13 plt.imshow(masked, cmap="Greys")
#      14 plt.title('greens')
#      15 plt.show()
#
# _pydevd_bundle\pydevd_cython_win32_37_64.pyx in _pydevd_bundle.pydevd_cython_win32_37_64.SafeCallWrapper.__call__()
#
# _pydevd_bundle\pydevd_cython_win32_37_64.pyx in _pydevd_bundle.pydevd_cython_win32_37_64.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle\pydevd_cython_win32_37_64.pyx in _pydevd_bundle.pydevd_cython_win32_37_64.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle\pydevd_cython_win32_37_64.pyx in _pydevd_bundle.pydevd_cython_win32_37_64.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle\pydevd_cython_win32_37_64.pyx in _pydevd_bundle.pydevd_cython_win32_37_64.PyDBFrame.do_wait_suspend()
#
# ~\AppData\Local\JetBrains\Toolbox\apps\PyCharm-P\ch-0\201.7846.77\plugins\python\helpers\pydev\pydevd.py in do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1101
#    1102         with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1103             self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#    1104
#    1105     def _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread):
#
# ~\AppData\Local\JetBrains\Toolbox\apps\PyCharm-P\ch-0\201.7846.77\plugins\python\helpers\pydev\pydevd.py in _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1116
#    1117                 self.process_internal_commands()
# -> 1118                 time.sleep(0.01)
#    1119
#    1120         self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#
# KeyboardInterrupt:

# %%
palette_x = 128
pallete_y = 7
digit_images = []
# Digit Images
for digit in range(10):
    origin_palette_x = palette_x + 8 * digit
    digit_images.append(
        masked[0:7, origin_palette_x:origin_palette_x+8]
    )
for i, digit_image in enumerate(digit_images):
    plt.imshow(digit_image, cmap="Greys")
    plt.title(f"{i}")
    plt.show()

# %%
snap_img = cv2.imread('samples/snap_762.png')
HSV_snap_img = cv2.cvtColor(snap_img, cv2.COLOR_BGR2HSV)
# 32, 23

cropped_image_hsv = HSV_snap_img[16:23, 24:72]
lower_white = np.array([0, 0, 250])
upper_bound = np.array([10, 10, 255])

white_mask = cv2.inRange(cropped_image_hsv, lower_white, upper_bound)
white_mask = cv2.bitwise_not(white_mask)

cropped_white_mask = white_mask[16:23, 24:72]

plt.imshow(white_mask, cmap="Greys")
plt.title(f"white_mask")
plt.show()

for i in range(6):
    cropped_digit = white_mask[0:7, 0+i*8:8+i*8]
    detected_digit = None
    for num, digit_image in enumerate(digit_images):
        xor_mask = cv2.bitwise_xor(cropped_digit, digit_image)
        count_nonzero = np.count_nonzero(xor_mask)
        plt.imshow(xor_mask, cmap="Greys")
        plt.title(f"mask {num}, count_nonzero {count_nonzero}")
        plt.show()
        if count_nonzero < 10:
            detected_digit = num


    plt.imshow(cropped_digit, cmap="Greys")
    plt.title(f"position {i}, detected_digit: {detected_digit}")
    plt.show()
