# %% [markdown]
# # Scratch

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('samples/snap_120.png')

RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

y = 0
x = 0
h = 100
w = 100

plt.imshow(RGB_img[y:y+h, x:x+w])
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='Greys_r')
plt.title('my picture')
plt.show()

# %%
ret,th1 = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)
plt.imshow(th1, cmap='Greys_r')
plt.title('my picture')
plt.show()

cv2.imwrite( 'masks/title.png', np.invert(th1))
# Out:
# True

# %%
np.size(th1)
# Out:
# 57344

# %%
np.count_nonzero(np.logical_and(th1, th1))
# Out:
# 52057

# %%
plt.imshow(np.logical_and(np.invert(th1), th1), cmap='Greys_r')
plt.title('my picture')
plt.show()

# %%
count = np.count_nonzero(np.logical_and(np.invert(th1), th1))
100*(3000) // th1.size
# Out:
# 5
